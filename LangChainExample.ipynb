# %%
##Connect to Google drive to read and write to files
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install langchain
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import os
os.environ["OPENAI_API_KEY"] = "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"

# %%
from langchain.llms import OpenAI
llm = OpenAI(model_name="text-davinci-003")

# %%
question = "Which is the best programming language to learn in 2023?"
print(llm(question))
# Out:
# It is difficult to say which is the best programming language to learn in 2023, as this will depend on what your specific needs and goals are. Popular languages in the past have included Python, Java, JavaScript, C++, and C#. Newer languages such as Go, Rust, and Kotlin are also gaining in popularity. Ultimately, it is best to research the language that best meets your needs and is most likely to be in demand in 2023.

# %%
question = "What are the top 4 resources to learn Golang in 2023?"
print(llm(question))
# Out:
# 1. Golang tutorials from the official Golang website.
# 2. Golang courses from Udemy.
# 3. Golang books from Amazon and other bookstores.
# 4. Golang articles and tutorials from various sources such as Medium, Reddit and Stack Overflow.

# %%
from langchain import PromptTemplate
template = "What are the top {k} threats to {this}?"
prompt = PromptTemplate(template=template,input_variables=['k','this'])

# %%
from langchain import LLMChain
chain = LLMChain(llm=llm,prompt=prompt)

# %%
input = {'k':3,'this':'wilsons bird of paradise'}
print(chain.run(input))
# Out:
# 1. Habitat Loss: Wilsons bird of paradise is limited to a few small areas of New Guinea, and its primary habitat is threatened by deforestation, mining, and agricultural expansion.
#
# 2. Predation: Wilsons bird of paradise is vulnerable to predation from introduced species such as rats, cats, and pigs.
#
# 3. Hunting: Hunting for food and for its feathers is a significant threat to the species.
